# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b>Apurv Chaudhary</b>
# Student

# %% [markdown]
# <i>I am interested in data science because of my love and fascination for analysis. I love the fact that we can use data to tell stories.</i>

# %% [markdown]
# <h3>In cell 5, we will calculate the square of 12</h3>

# %%
print("the square of 12 is:")
print(12*12)
# Out:
# the square of 12 is:
# 144

# %% [markdown]
# 1. this is number list 1
# 2. this is number list 2
# 3. this is number list 3
#
# END 1
#
# - this is bullet list 1
# - this is bullet list 2
# - this is bullet list 3
#
# END 2
#
# ~~displaying strikethrough~~
#
# END 3
